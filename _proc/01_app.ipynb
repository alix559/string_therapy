# %% [raw]
# ---
# description: main script
# output-file: app.html
# title: App
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
from fasthtml.common import *
from monsterui.all import *
from starlette.responses import Response

import inspect 
import os 
import sys 
import threading 
import webbrowser
from string_therapy.icon1 import NOTEBOOK_ICON_ID, SESSION_EDITOR_KEY, SESSION_MD_KEY

# %% [markdown]
# so we have 4 icons here :
# 1. a markdown view with edit capabilities
# 2. an obsidian style data visualization of all the markdowns
# 3. a panel to add or make new markdowns
# 4. jupyter kernel
