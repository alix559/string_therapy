# %% [raw]
# ---
# output-file: untitled.html
# title: Spawn the Jupyter Lab alongside the string therapy FastHTML app when auto start
#   is enabled
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# uses the same ServerApp flags as ``pixi.toml`` ``[tasks.jupyter-lab]`` . If something already listens on ``JUPYTER_PORT``, startup is skipped

# %%
#| echo: false
#| output: asis
show_doc(stop_embedded_jupyter_lab)
# Out:
# def stop_embedded_jupyter_lab(
#     proc:subprocess.Popen | None
# )->None:
# """Terminate an embedded Lab process from ``start_embedded_jupyter_lab``.
#
# No-op if ``proc`` is ``None`` or already exited. Sends SIGTERM, waits up to 8s,
# then SIGKILL on timeout."""

# %%
#| echo: false
#| output: asis
show_doc(start_embedded_jupyter_lab)
# Out:
# def start_embedded_jupyter_lab(
#
# )->subprocess.Popen | None:
# """Start ``jupyter lab`` in the background when allowed and the port is free.
#
# Skips when ``auto_jupyter_enabled()`` is false, ``jupyter`` is missing from
# ``PATH``, or ``_port_free`` is false (assumes Lab already runs). Logs to
# ``stderr`` in those cases.
#
# Returns:
#     The child process, or ``None`` if Lab was not started."""

# %%
#| echo: false
#| output: asis
show_doc(jupyter_lab_argv)
# Out:
# def jupyter_lab_argv(
#
# )->list[str]:
# """Build the ``jupyter lab`` argument list aligned with ``pixi.toml`` tasks.
#
# Uses ``JUPYTER_HOST``, ``JUPYTER_PORT``, and optionally ``--collaborative``
# (see ``_collaborative``). Token/password are empty; CSP allows iframe embedding."""

# %%
#| echo: false
#| output: asis
show_doc(auto_jupyter_enabled)
# Out:
# def auto_jupyter_enabled(
#
# )->bool:
# """Return whether ``app.py`` may spawn an embedded Jupyter Lab process.
#
# ``ST_AUTO_JUPYTER`` must be ``true`` or ``false`` (case-insensitive);
# when unset, defaults to ``true``. Set ``false`` to run Lab yourself (e.g. ``pixi run jupyter-lab``)."""
